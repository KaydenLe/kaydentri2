# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: MCQ3 Reflection
# courses: {'compsci': {'week':25}}
# type: hacks
# ---

# %% [markdown]
# This is my reflection for the 2021 APCSP Exam
#
# Overallscore:
# <img width="1704" alt="Screenshot 2024-03-15 at 8 46 58 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/6e9ff0f8-d493-48df-a396-9588204a2934">
#
# Question 3:
# <img width="1105" alt="Screenshot 2024-03-15 at 8 57 29 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/633acae4-4cfe-43f7-bfd3-e305193fb6c9">
# Reflection: I didn't understand this question because of the first and then it goes back to the second so I thought they both equal 200.
#
# Question 9:
# <img width="1099" alt="Screenshot 2024-03-15 at 8 58 44 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/ea1f3403-fc7b-43a2-bcaa-aaf09482beca">
# Reflection: I don't know what an analog audio signal is so I guessed on this one.
#
# Question 10:
# <img width="1096" alt="Screenshot 2024-03-15 at 9 00 31 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/21689610-4ce5-4a6a-b118-f357bb2f9882">
# Reflection: I didn't under stand this question because I how do the numbers correlate with the binary value.
#
# Question 12:
# <img width="941" alt="Screenshot 2024-03-15 at 9 01 48 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/02e739e7-c2f2-4888-a11a-2120eb2a1143">
# Reflection: I didn't notice that it repeats and I thought you would to move forward and turn left.
#
# Question 14:
# <img width="1106" alt="Screenshot 2024-03-15 at 9 03 56 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/df3ef044-2dd5-4680-9503-a3281c9fc837">
# Reflection: I didn't understand this question and why 8 and 12 is the correct answer but I thought line 6 was wrong because it seemed like it was the only logical answer because I didn't think any of the other lines had issues.
#
# Question 17:
# <img width="1099" alt="Screenshot 2024-03-15 at 9 04 36 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/5754cbfa-9173-42d2-aba5-91b70d630b68">
# Reflection: I don't understand this question because I don't understand the diagram and I don't understand the options for the answer.
#
# Question 22:
# <img width="707" alt="Screenshot 2024-03-15 at 9 05 29 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/fec61368-6d46-4fc2-b17a-b1bc4680f156">
# Reflection: I wasn't sure if this question was asking to have the mouse go back to the center of the grid because it was already in the center and so I guessed.
#
# Question 23:
# <img width="1102" alt="Screenshot 2024-03-15 at 9 06 10 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/266f18dc-74f0-40dd-b4df-b1cbb53d0dfa">
# Reflection: I got this question wrong because I genuinely didn't know which one is a true statement,
#
# Question 24:
# <img width="1110" alt="Screenshot 2024-03-15 at 9 07 12 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/70bdb356-53df-44bb-b938-d485be5a6d3e">
# Reflection: I didn't understand this question because I don't know what lassy compression means and lossless compression.
#
# Question 28:
# <img width="1125" alt="Screenshot 2024-03-15 at 9 07 49 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/69dd5f01-f579-4562-8182-c5ad40767c97">
# Reflection: I didn't understand this question and what the choices for the answer because I don't get how is the outcome 5 and -5.
#
# Question 42
# <img width="1104" alt="Screenshot 2024-03-15 at 9 08 11 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/06afd727-2b57-44f6-b38c-ff417cc78905">
# Reflection: I got this question wrong because I didn't understand what value was being displayed because I didn't understand how it would be one value such as 3.
#
# Question 47
# <img width="1100" alt="Screenshot 2024-03-15 at 9 08 47 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/3815d042-2037-4efc-9725-8778fd45bd87">
# Reflection: I got this wrong because I didn't see the difference between "AND" and "OR".
#
# Question 53:
# <img width="1099" alt="Screenshot 2024-03-15 at 9 09 15 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/bae86aaf-c757-48cb-9d09-c2fa4bd4dd60">
# Reflection: I got this wrong because I thought it had to repeat steps 2 and 3 but it didn't know it had to equal to 2.
#
# Question 55:
# <img width="1101" alt="Screenshot 2024-03-15 at 9 10 01 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/92a2bb5d-106f-4b6c-b9ce-51322fe8f6ed">
# Reflection: I got this wrong because I was running out of time so I skimmed through the answers and made a guest.
#
# Question 57:
# <img width="1103" alt="Screenshot 2024-03-15 at 9 10 43 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/d1517a2d-3dcf-47e5-b310-efb9d4dc1143">
# Reflection: I got this wrong because I thought P and R would minimize it because they both take the longest.
#
# Question 60:
# <img width="1090" alt="Screenshot 2024-03-15 at 9 11 05 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/17aec684-91c5-49be-a995-9cfc83c96bc0">
# Reflection: I got this wrong because I was running out of time so I guest
#
# Question 61:
# <img width="1092" alt="Screenshot 2024-03-15 at 9 13 39 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/4e198d92-bdce-4849-a277-fa989f9a27c1">
# Reflection: I got this wrong so I skimmed through the question and guessed.
#
# Question 62:
# <img width="1093" alt="Screenshot 2024-03-15 at 9 14 17 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/d68fce8c-e2d0-4fc7-9bc8-458d82357de1">
# Reflection: I got this wrong because I was running out of time so I guessed.
#
# Question 67:
# <img width="1113" alt="Screenshot 2024-03-15 at 9 15 18 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/173e2b36-c115-4327-841c-4aec6cf5951d">
# Reflection: I got this wrong because I was running out of time because I knew it was A but I didn't know the other answer so I made a guess.
#
# Question 70:
# <img width="1105" alt="Screenshot 2024-03-15 at 9 15 56 AM" src="https://github.com/KaydenLe/kaydentri2/assets/142542385/4a41e642-34b5-4e5e-ad3d-df5328904cda">
# Reflection: I got this wrong because I was running out of time so I guessed.
